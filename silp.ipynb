# %%
import os
from PIL import Image
from torchvision.transforms import ToTensor
import torch

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir_occluded1, root_dir_occluded2, root_dir_clear, transform=None):
        self.root_dir_occluded1 = root_dir_occluded1
        self.root_dir_occluded2 = root_dir_occluded2
        self.root_dir_clear = root_dir_clear
        self.transform = transform

        # Collect all image paths from nested directories for occluded images 1
        self.occluded1_image_paths = []
        for root, _, files in os.walk(root_dir_occluded1):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    self.occluded1_image_paths.append(os.path.join(root, file))

        # Collect all image paths from nested directories for occluded images 2
        self.occluded2_image_paths = []
        for root, _, files in os.walk(root_dir_occluded2):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    self.occluded2_image_paths.append(os.path.join(root, file))

        # Collect all image paths from nested directories for clear images
        self.clear_image_paths = []
        for root, _, files in os.walk(root_dir_clear):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    self.clear_image_paths.append(os.path.join(root, file))

    def __len__(self):
        return len(self.occluded1_image_paths) + len(self.occluded2_image_paths) + len(self.clear_image_paths)

    def __getitem__(self, idx):
        if idx < len(self.occluded1_image_paths):
            img_name = self.occluded1_image_paths[idx]
            label = 0  
        elif idx < len(self.occluded1_image_paths) + len(self.occluded2_image_paths):
            img_name = self.occluded2_image_paths[idx - len(self.occluded1_image_paths)]
            label = 0  
        else:
            img_name = self.clear_image_paths[idx - len(self.occluded1_image_paths) - len(self.occluded2_image_paths)]
            label = 1 
        
        image = Image.open(img_name)
        
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
import os
from PIL import Image
from torchvision.transforms import ToTensor
import torch

class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir_occluded1, root_dir_occluded2, root_dir_clear, transform=None):
        self.root_dir_occluded1 = root_dir_occluded1
        self.root_dir_occluded2 = root_dir_occluded2
        self.root_dir_clear = root_dir_clear
        self.transform = transform

        # Collect all image paths from nested directories for occluded images 1
        self.occluded1_image_paths = []
        print("Scanning occluded images 1 directory...")
        for root, _, files in os.walk(root_dir_occluded1):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    img_path = os.path.join(root, file)
                    self.occluded1_image_paths.append(img_path)
                    print("Found occluded image 1:", img_path)

        # Collect all image paths from nested directories for occluded images 2
        self.occluded2_image_paths = []
        print("Scanning occluded images 2 directory...")
        for root, _, files in os.walk(root_dir_occluded2):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    img_path = os.path.join(root, file)
                    self.occluded2_image_paths.append(img_path)
                    print("Found occluded image 2:", img_path)

        # Collect all image paths from nested directories for clear images
        self.clear_image_paths = []
        print("Scanning clear images directory...")
        for root, _, files in os.walk(root_dir_clear):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    img_path = os.path.join(root, file)
                    self.clear_image_paths.append(img_path)
                    print("Found clear image:", img_path)

    def __len__(self):
        return len(self.occluded1_image_paths) + len(self.occluded2_image_paths) + len(self.clear_image_paths)

    def __getitem__(self, idx):
        if idx < len(self.occluded1_image_paths):
            img_name = self.occluded1_image_paths[idx]
            label = 0  
        elif idx < len(self.occluded1_image_paths) + len(self.occluded2_image_paths):
            img_name = self.occluded2_image_paths[idx - len(self.occluded1_image_paths)]
            label = 0  
        else:
            img_name = self.clear_image_paths[idx - len(self.occluded1_image_paths) - len(self.occluded2_image_paths)]
            label = 1 
        
        image = Image.open(img_name)
        
        if self.transform:
            image = self.transform(image)

        return image, label

# %%
from torchvision.transforms import Compose, Resize, ToTensor
from torch.utils.data import DataLoader

batch_size = 32
shuffle=True
transform = Compose([
    Resize((224, 224)),
    ToTensor(),
])
root_dir_occluded1=r'masked'
root_dir_occluded2=r'sunglasses'
root_dir_clear=r'neutral'
my_dataset = CustomDataset(root_dir_occluded1, root_dir_occluded2, root_dir_clear, transform=transform)
data_loader = DataLoader(my_dataset, batch_size=batch_size, shuffle=shuffle)
# Out:
# Scanning occluded images 1 directory...
# Scanning occluded images 2 directory...
# Scanning clear images directory...
# Found clear image: neutral\adrien_brody\000001.jpg
# Found clear image: neutral\adrien_brody\000002.jpg
# Found clear image: neutral\adrien_brody\000003.jpg
# Found clear image: neutral\adrien_brody\000004.jpg
# Found clear image: neutral\adrien_brody\000005.jpg
# Found clear image: neutral\adrien_brody\000006.jpg
# Found clear image: neutral\adrien_brody\000007.jpg
# Found clear image: neutral\adrien_brody\000008.jpg
# Found clear image: neutral\adrien_brody\000009.jpg
# Found clear image: neutral\adrien_brody\000010.jpg
# Found clear image: neutral\adrien_brody\000011.jpg
# Found clear image: neutral\adrien_brody\000012.jpg
# Found clear image: neutral\adrien_brody\000013.jpg
# Found clear image: neutral\adrien_brody\000014.jpg
# Found clear image: neutral\adrien_brody\000015.jpg
# Found clear image: neutral\adrien_brody\000016.jpg
# Found clear image: neutral\adrien_brody\000017.jpg
# Found clear image: neutral\adrien_brody\000018.jpg
# Found clear image: neutral\adrien_brody\000019.jpg
# Found clear image: neutral\adrien_brody\000020.jpg
# Found clear image: neutral\adrien_brody\000021.jpg
# Found clear image: neutral\adrien_brody\000022.jpg
# Found clear image: neutral\alain_delon\000001.jpg
# Found clear image: neutral\alain_delon\000002.jpg
# Found clear image: neutral\alain_delon\000003.jpg
# Found clear image: neutral\alain_delon\000004.jpg
# Found clear image: neutral\alain_delon\000005.jpg
# Found clear image: neutral\alain_delon\000006.jpg
# Found clear image: neutral\alain_delon\000007.jpg
# Found clear image: neutral\alain_delon\000008.jpg
# Found clear image: neutral\alain_delon\000009.jpg
# Found clear image: neutral\alain_delon\000010.jpg
# Found clear image: neutral\alain_delon\000011.jpg
# Found clear image: neutral\alain_delon\000012.jpg
# Found clear image: neutral\alain_delon\000013.jpg
# Found clear image: neutral\alain_delon\000014.jpg
# Found clear image: neutral\alain_delon\000015.jpg
# Found clear image: neutral\alain_delon\000016.jpg
# Found clear image: neutral\alain_delon\000017.jpg
# Found clear image: neutral\alain_delon\000018.jpg
# Found clear image: neutral\alain_delon\000019.jpg
# Found clear image: neutral\alexander_zverev\000001.jpg
# Found clear image: neutral\alexander_zverev\000002.jpg
# Found clear image: neutral\alexander_zverev\000003.jpg
# Found clear image: neutral\alexander_zverev\000004.jpg
# Found clear image: neutral\alexander_zverev\000005.jpg
# Found clear image: neutral\alexander_zverev\000006.jpg
# Found clear image: neutral\alexander_zverev\000007.jpg
# Found clear image: neutral\alexander_zverev\000008.jpg
# Found clear image: neutral\alexander_zverev\000009.jpg
# Found clear image: neutral\alexander_zverev\000010.jpg
# Found clear image: neutral\alexander_zverev\000011.jpg
# Found clear image: neutral\alexander_zverev\000012.jpg
# Found clear image: neutral\alexander_zverev\000013.jpg
# Found clear image: neutral\alexander_zverev\000014.jpg
# Found clear image: neutral\alexander_zverev\000015.jpg
# Found clear image: neutral\alexander_zverev\000016.jpg
# Found clear image: neutral\alexander_zverev\000017.jpg
# Found clear image: neutral\alexander_zverev\000018.jpg
# Found clear image: neutral\alexander_zverev\000019.jpg
# Found clear image: neutral\alexander_zverev\000020.jpg
# Found clear image: neutral\alexander_zverev\000021.jpg
# Found clear image: neutral\alexander_zverev\000022.jpg
# Found clear image: neutral\alexander_zverev\000023.jpg
# Found clear image: neutral\al_pacino\000001.jpg
# Found clear image: neutral\al_pacino\000002.jpg
# Found clear image: neutral\al_pacino\000003.jpg
# Found clear image: neutral\al_pacino\000004.jpg
# Found clear image: neutral\al_pacino\000005.jpg
# Found clear image: neutral\al_pacino\000006.jpg
# Found clear image: neutral\al_pacino\000007.jpg
# Found clear image: neutral\al_pacino\000008.jpg
# Found clear image: neutral\al_pacino\000009.jpg
# Found clear image: neutral\al_pacino\000010.jpg
# Found clear image: neutral\al_pacino\000011.jpg
# Found clear image: neutral\al_pacino\000012.jpg
# Found clear image: neutral\al_pacino\000013.jpg
# Found clear image: neutral\al_pacino\000014.jpg
# Found clear image: neutral\al_pacino\000015.jpg
# Found clear image: neutral\amber_heard\000001.jpg
# Found clear image: neutral\amber_heard\000002.jpg
# Found clear image: neutral\amber_heard\000003.jpg
# Found clear image: neutral\amber_heard\000004.jpg
# Found clear image: neutral\amber_heard\000005.jpg
# Found clear image: neutral\amber_heard\000006.jpg
# Found clear image: neutral\amber_heard\000007.jpg
# Found clear image: neutral\amber_heard\000008.jpg
# Found clear image: neutral\amber_heard\000009.jpg
# Found clear image: neutral\amber_heard\000010.jpg
# Found clear image: neutral\amber_heard\000011.jpg
# Found clear image: neutral\amber_heard\000012.jpg
# Found clear image: neutral\amber_heard\000013.jpg
# Found clear image: neutral\amber_heard\000014.jpg
# Found clear image: neutral\amber_heard\000015.jpg
# Found clear image: neutral\amber_heard\000016.jpg
# Found clear image: neutral\amber_heard\000017.jpg
# Found clear image: neutral\amber_heard\000018.jpg
# Found clear image: neutral\amber_heard\000019.jpg
# Found clear image: neutral\amber_heard\000020.jpg
# Found clear image: neutral\amber_heard\000021.jpg
# Found clear image: neutral\amber_heard\000022.jpg
# Found clear image: neutral\amber_heard\000023.jpg
# Found clear image: neutral\amy_klobuchar\000001.jpg
# Found clear image: neutral\amy_klobuchar\000002.jpg
# Found clear image: neutral\amy_klobuchar\000003.jpg
# Found clear image: neutral\amy_klobuchar\000004.jpg
# Found clear image: neutral\amy_klobuchar\000005.jpg
# Found clear image: neutral\amy_klobuchar\000006.jpg
# Found clear image: neutral\amy_klobuchar\000007.jpg
# Found clear image: neutral\amy_klobuchar\000008.jpg
# Found clear image: neutral\amy_klobuchar\000009.jpg
# Found clear image: neutral\amy_klobuchar\000010.jpg
# Found clear image: neutral\amy_klobuchar\000011.jpg
# Found clear image: neutral\amy_klobuchar\000012.jpg
# Found clear image: neutral\amy_klobuchar\000013.jpg
# Found clear image: neutral\amy_klobuchar\000014.jpg
# Found clear image: neutral\amy_klobuchar\000015.jpg
# Found clear image: neutral\amy_klobuchar\000016.jpg
# Found clear image: neutral\amy_klobuchar\000017.jpg
# Found clear image: neutral\amy_klobuchar\000018.jpg
# Found clear image: neutral\amy_klobuchar\000019.jpg
# Found clear image: neutral\amy_klobuchar\000020.jpg
# Found clear image: neutral\amy_klobuchar\000021.jpg
# Found clear image: neutral\amy_klobuchar\000022.jpg
# Found clear image: neutral\amy_klobuchar\000023.jpg
# Found clear image: neutral\amy_klobuchar\000024.jpg
# Found clear image: neutral\amy_klobuchar\000025.jpg
# Found clear image: neutral\amy_klobuchar\000026.jpg
# Found clear image: neutral\amy_klobuchar\000027.jpg
# Found clear image: neutral\andrey_rublev\000001.jpg
# Found clear image: neutral\andrey_rublev\000002.jpg
# Found clear image: neutral\andrey_rublev\000003.jpg
# Found clear image: neutral\andrey_rublev\000004.jpg
# Found clear image: neutral\andrey_rublev\000005.jpg
# Found clear image: neutral\andrey_rublev\000006.jpg
# Found clear image: neutral\andrey_rublev\000007.jpg
# Found clear image: neutral\andrey_rublev\000008.jpg
# Found clear image: neutral\andrey_rublev\000009.jpg
# Found clear image: neutral\andrey_rublev\000010.jpg
# Found clear image: neutral\andrey_rublev\000011.jpg
# Found clear image: neutral\andrey_rublev\000012.jpg
# Found clear image: neutral\andrey_rublev\000013.jpg
# Found clear image: neutral\andrey_rublev\000014.jpg
# Found clear image: neutral\andrey_rublev\000015.jpg
# Found clear image: neutral\andrey_rublev\000016.jpg
# Found clear image: neutral\andrey_rublev\000017.jpg
# Found clear image: neutral\andrey_rublev\000018.jpg
# Found clear image: neutral\andrey_rublev\000019.jpg
# Found clear image: neutral\andrey_rublev\000020.jpg
# Found clear image: neutral\andrey_rublev\000021.jpg
# Found clear image: neutral\andrey_rublev\000022.jpg
# Found clear image: neutral\anne_hathaway\000001.jpg
# Found clear image: neutral\anne_hathaway\000002.jpg
# Found clear image: neutral\anne_hathaway\000003.jpg
# Found clear image: neutral\anne_hathaway\000004.jpg
# Found clear image: neutral\anne_hathaway\000005.jpg
# Found clear image: neutral\anne_hathaway\000006.jpg
# Found clear image: neutral\anne_hathaway\000007.jpg
# Found clear image: neutral\anne_hathaway\000008.jpg
# Found clear image: neutral\anne_hathaway\000009.jpg
# Found clear image: neutral\anne_hathaway\000010.jpg
# Found clear image: neutral\anne_hathaway\000011.jpg
# Found clear image: neutral\anne_hathaway\000012.jpg
# Found clear image: neutral\anne_hathaway\000013.jpg
# Found clear image: neutral\anthony_mackie\000017.jpg
# Found clear image: neutral\anthony_mackie\000018.jpg
# Found clear image: neutral\anthony_mackie\000019.jpg
# Found clear image: neutral\anthony_mackie\000020.jpg
# Found clear image: neutral\anthony_mackie\000021.jpg
# Found clear image: neutral\anthony_mackie\000022.jpg
# Found clear image: neutral\anthony_mackie\000023.jpg
# Found clear image: neutral\anthony_mackie\000024.jpg
# Found clear image: neutral\antonio_banderas\000001.jpg
# Found clear image: neutral\antonio_banderas\000002.jpg
# Found clear image: neutral\antonio_banderas\000003.jpg
# Found clear image: neutral\antonio_banderas\000004.jpg
# Found clear image: neutral\antonio_banderas\000005.jpg
# Found clear image: neutral\antonio_banderas\000006.jpg
# Found clear image: neutral\antonio_banderas\000007.jpg
# Found clear image: neutral\antonio_banderas\000008.jpg
# Found clear image: neutral\antonio_banderas\000009.jpg
# Found clear image: neutral\antonio_banderas\000010.jpg
# Found clear image: neutral\antonio_banderas\000011.jpg
# Found clear image: neutral\antonio_banderas\000012.jpg
# Found clear image: neutral\antonio_banderas\000013.jpg
# Found clear image: neutral\arnold_schwarzenegger\000001.jpg
# Found clear image: neutral\arnold_schwarzenegger\000002.jpg
# Found clear image: neutral\arnold_schwarzenegger\000003.jpg
# Found clear image: neutral\arnold_schwarzenegger\000004.jpg
# Found clear image: neutral\arnold_schwarzenegger\000005.jpg
# Found clear image: neutral\arnold_schwarzenegger\000006.jpg
# Found clear image: neutral\arnold_schwarzenegger\000007.jpg
# Found clear image: neutral\arnold_schwarzenegger\000008.jpg
# Found clear image: neutral\arnold_schwarzenegger\000009.jpg
# Found clear image: neutral\arnold_schwarzenegger\000010.jpg
# Found clear image: neutral\arnold_schwarzenegger\000011.jpg
# Found clear image: neutral\arnold_schwarzenegger\000012.jpg
# Found clear image: neutral\arnold_schwarzenegger\000013.jpg
# Found clear image: neutral\benedict_cumberbatch\000001.jpg
# Found clear image: neutral\benedict_cumberbatch\000002.jpg
# Found clear image: neutral\benedict_cumberbatch\000003.jpg
# Found clear image: neutral\benedict_cumberbatch\000004.jpg
# Found clear image: neutral\benedict_cumberbatch\000005.jpg
# Found clear image: neutral\benedict_cumberbatch\000006.jpg
# Found clear image: neutral\benedict_cumberbatch\000007.jpg
# Found clear image: neutral\benedict_cumberbatch\000008.jpg
# Found clear image: neutral\benedict_cumberbatch\000009.jpg
# Found clear image: neutral\benedict_cumberbatch\000010.jpg
# Found clear image: neutral\benedict_cumberbatch\000011.jpg
# Found clear image: neutral\benedict_cumberbatch\000012.jpg
# Found clear image: neutral\benedict_cumberbatch\000013.jpg
# Found clear image: neutral\benedict_cumberbatch\000014.jpg
# Found clear image: neutral\benedict_cumberbatch\000015.jpg
# Found clear image: neutral\benedict_cumberbatch\000016.jpg
# Found clear image: neutral\benedict_cumberbatch\000017.jpg
# Found clear image: neutral\benedict_cumberbatch\000018.jpg
# Found clear image: neutral\benedict_cumberbatch\000019.jpg
# Found clear image: neutral\benedict_cumberbatch\000020.jpg
# Found clear image: neutral\benedict_cumberbatch\000021.jpg
# Found clear image: neutral\benedict_cumberbatch\000022.jpg
# Found clear image: neutral\benedict_cumberbatch\000023.jpg
# Found clear image: neutral\benedict_cumberbatch\000024.jpg
# Found clear image: neutral\benedict_cumberbatch\000025.jpg
# Found clear image: neutral\benedict_cumberbatch\000026.jpg
# Found clear image: neutral\benedict_cumberbatch\000027.jpg
# Found clear image: neutral\benedict_cumberbatch\000028.jpg
# Found clear image: neutral\benedict_cumberbatch\000029.jpg
# Found clear image: neutral\benedict_cumberbatch\000030.jpg
# Found clear image: neutral\benedict_cumberbatch\000031.jpg
# Found clear image: neutral\benedict_cumberbatch\000032.jpg
# Found clear image: neutral\benedict_cumberbatch\000033.jpg
# Found clear image: neutral\benedict_cumberbatch\000034.jpg
# Found clear image: neutral\benedict_cumberbatch\000035.jpg
# Found clear image: neutral\benedict_cumberbatch\000036.jpg
# Found clear image: neutral\benedict_cumberbatch\000037.jpg
# Found clear image: neutral\benedict_cumberbatch\000038.jpg
# Found clear image: neutral\benedict_cumberbatch\000039.jpg
# Found clear image: neutral\benedict_cumberbatch\000040.jpg
# Found clear image: neutral\benedict_cumberbatch\000041.jpg
# Found clear image: neutral\benedict_cumberbatch\000042.jpg
# Found clear image: neutral\benedict_cumberbatch\000043.jpg
# Found clear image: neutral\benedict_cumberbatch\000044.jpg
# Found clear image: neutral\benedict_cumberbatch\000045.jpg
# Found clear image: neutral\benedict_cumberbatch\000046.jpg
# Found clear image: neutral\benedict_cumberbatch\000047.jpg
# Found clear image: neutral\benedict_cumberbatch\000048.jpg
# Found clear image: neutral\benedict_cumberbatch\000049.jpg
# Found clear image: neutral\benedict_cumberbatch\000050.jpg
# Found clear image: neutral\benedict_cumberbatch\000051.jpg
# Found clear image: neutral\benedict_cumberbatch\000052.jpg
# Found clear image: neutral\benedict_cumberbatch\000053.jpg
# Found clear image: neutral\benedict_cumberbatch\000054.jpg
# Found clear image: neutral\benedict_cumberbatch\000055.jpg
# Found clear image: neutral\benedict_cumberbatch\000056.jpg
# Found clear image: neutral\benedict_cumberbatch\000057.jpg
# Found clear image: neutral\benedict_cumberbatch\000058.jpg
# Found clear image: neutral\benedict_cumberbatch\000059.jpg
# Found clear image: neutral\benedict_cumberbatch\000060.jpg
# Found clear image: neutral\benedict_cumberbatch\000061.jpg
# Found clear image: neutral\ben_mendelsohn\000001.jpg
# Found clear image: neutral\ben_mendelsohn\000002.jpg
# Found clear image: neutral\ben_mendelsohn\000003.jpg
# Found clear image: neutral\ben_mendelsohn\000004.jpg
# Found clear image: neutral\ben_mendelsohn\000005.jpg
# Found clear image: neutral\ben_mendelsohn\000006.jpg
# Found clear image: neutral\ben_mendelsohn\000007.jpg
# Found clear image: neutral\ben_mendelsohn\000008.jpg
# Found clear image: neutral\ben_mendelsohn\000009.jpg
# Found clear image: neutral\ben_mendelsohn\000010.jpg
# Found clear image: neutral\ben_mendelsohn\000011.jpg
# Found clear image: neutral\ben_mendelsohn\000012.jpg
# Found clear image: neutral\ben_mendelsohn\000013.jpg
# Found clear image: neutral\bernard_arnault\000007.jpg
# Found clear image: neutral\bernard_arnault\000008.jpg
# Found clear image: neutral\bernard_arnault\000009.jpg
# Found clear image: neutral\bernard_arnault\000010.jpg
# Found clear image: neutral\bernard_arnault\000011.jpg
# Found clear image: neutral\bernard_arnault\000012.jpg
# Found clear image: neutral\bernard_arnault\000013.jpg
# Found clear image: neutral\bernard_arnault\000014.jpg
# Found clear image: neutral\bernard_arnault\000015.jpg
# Found clear image: neutral\bernard_arnault\000016.jpg
# Found clear image: neutral\bernard_arnault\000017.jpg
# Found clear image: neutral\bernard_arnault\000018.jpg
# Found clear image: neutral\bernard_arnault\000019.jpg
# Found clear image: neutral\bernard_arnault\000020.jpg
# Found clear image: neutral\bernard_arnault\000021.jpg
# Found clear image: neutral\bernard_arnault\000022.jpg
# Found clear image: neutral\bernard_arnault\000023.jpg
# Found clear image: neutral\bernard_arnault\000024.jpg
# Found clear image: neutral\bernard_arnault\000025.jpg
# Found clear image: neutral\bernard_arnault\000026.jpg
# Found clear image: neutral\bernie_sanders\000001.jpg
# Found clear image: neutral\bernie_sanders\000002.jpg
# Found clear image: neutral\bernie_sanders\000003.jpg
# Found clear image: neutral\bernie_sanders\000004.jpg
# Found clear image: neutral\bernie_sanders\000005.jpg
# Found clear image: neutral\bernie_sanders\000006.jpg
# Found clear image: neutral\bernie_sanders\000007.jpg
# Found clear image: neutral\bernie_sanders\000008.jpg
# Found clear image: neutral\bernie_sanders\000009.jpg
# Found clear image: neutral\bernie_sanders\000010.jpg
# Found clear image: neutral\bernie_sanders\000011.jpg
# Found clear image: neutral\bernie_sanders\000012.jpg
# Found clear image: neutral\bernie_sanders\000013.jpg
# Found clear image: neutral\bill_gates\000001.jpg
# Found clear image: neutral\bill_gates\000002.jpg
# Found clear image: neutral\bill_gates\000003.jpg
# Found clear image: neutral\bill_gates\000004.jpg
# Found clear image: neutral\bill_gates\000005.jpg
# Found clear image: neutral\bill_gates\000006.jpg
# Found clear image: neutral\bill_gates\000007.jpg
# Found clear image: neutral\bill_gates\000008.jpg
# Found clear image: neutral\bill_gates\000009.jpg
# Found clear image: neutral\bill_gates\000010.jpg
# Found clear image: neutral\bill_gates\000011.jpg
# Found clear image: neutral\bill_gates\000012.jpg
# Found clear image: neutral\bill_gates\000013.jpg
# Found clear image: neutral\bill_gates\000014.jpg
# Found clear image: neutral\bill_gates\000015.jpg
# Found clear image: neutral\bill_gates\000016.jpg
# Found clear image: neutral\bill_gates\000017.jpg
# Found clear image: neutral\bill_gates\000018.jpg
# Found clear image: neutral\bill_gates\000019.jpg
# Found clear image: neutral\bill_gates\000020.jpg
# Found clear image: neutral\bill_gates\000021.jpg
# Found clear image: neutral\bill_gates\000022.jpg
# Found clear image: neutral\bill_gates\000023.jpg
# Found clear image: neutral\bill_gates\000024.jpg
# Found clear image: neutral\bill_gates\000025.jpg
# Found clear image: neutral\bill_gates\000026.jpg
# Found clear image: neutral\bill_gates\000027.jpg
# Found clear image: neutral\bill_gates\000028.jpg
# Found clear image: neutral\bill_gates\000029.jpg
# Found clear image: neutral\bill_gates\000030.jpg
# Found clear image: neutral\brad_pitt\000001.jpg
# Found clear image: neutral\brad_pitt\000002.jpg
# Found clear image: neutral\brad_pitt\000003.jpg
# Found clear image: neutral\brad_pitt\000004.jpg
# Found clear image: neutral\brad_pitt\000005.jpg
# Found clear image: neutral\brad_pitt\000006.jpg
# Found clear image: neutral\brad_pitt\000007.jpg
# Found clear image: neutral\brad_pitt\000008.jpg
# Found clear image: neutral\brad_pitt\000009.jpg
# Found clear image: neutral\brad_pitt\000010.jpg
# Found clear image: neutral\brad_pitt\000011.jpg
# Found clear image: neutral\brad_pitt\000012.jpg
# Found clear image: neutral\brad_pitt\000013.jpg
# Found clear image: neutral\brad_pitt\000014.jpg
# Found clear image: neutral\brad_pitt\000015.jpg
# Found clear image: neutral\brad_pitt\000016.jpg
# Found clear image: neutral\brad_pitt\000017.jpg
# Found clear image: neutral\brad_pitt\000018.jpg
# Found clear image: neutral\brad_pitt\000019.jpg
# Found clear image: neutral\brad_pitt\000020.jpg
# Found clear image: neutral\brad_pitt\000021.jpg
# Found clear image: neutral\brad_pitt\000022.jpg
# Found clear image: neutral\brad_pitt\000023.jpg
# Found clear image: neutral\brad_pitt\000024.jpg
# Found clear image: neutral\brad_pitt\000025.jpg
# Found clear image: neutral\brad_pitt\000026.jpg
# Found clear image: neutral\brad_pitt\000027.jpg
# Found clear image: neutral\brad_pitt\000028.jpg
# Found clear image: neutral\brad_pitt\000029.jpg
# Found clear image: neutral\brad_pitt\000030.jpg
# Found clear image: neutral\brad_pitt\000031.jpg
# Found clear image: neutral\brad_pitt\000032.jpg
# Found clear image: neutral\brad_pitt\000033.jpg
# Found clear image: neutral\brad_pitt\000034.jpg
# Found clear image: neutral\brad_pitt\000035.jpg
# Found clear image: neutral\brad_pitt\000036.jpg
# Found clear image: neutral\brad_pitt\000037.jpg
# Found clear image: neutral\brad_pitt\000038.jpg
# Found clear image: neutral\brad_pitt\000039.jpg
# Found clear image: neutral\brad_pitt\000040.jpg
# Found clear image: neutral\brad_pitt\000041.jpg
# Found clear image: neutral\brad_pitt\000042.jpg
# Found clear image: neutral\brad_pitt\000043.jpg
# Found clear image: neutral\brad_pitt\000044.jpg
# Found clear image: neutral\brad_pitt\000045.jpg
# Found clear image: neutral\brad_pitt\000046.jpg
# Found clear image: neutral\brad_pitt\000047.jpg
# Found clear image: neutral\brad_pitt\000048.jpg
# Found clear image: neutral\brad_pitt\000049.jpg
# Found clear image: neutral\brad_pitt\000050.jpg
# Found clear image: neutral\brad_pitt\000051.jpg
# Found clear image: neutral\brad_pitt\000052.jpg
# Found clear image: neutral\brad_pitt\000053.jpg
# Found clear image: neutral\brad_pitt\000054.jpg
# Found clear image: neutral\brad_pitt\000055.jpg
# Found clear image: neutral\brad_pitt\000056.jpg
# Found clear image: neutral\brie_larson\000001.jpg
# Found clear image: neutral\brie_larson\000002.jpg
# Found clear image: neutral\brie_larson\000003.jpg
# Found clear image: neutral\brie_larson\000004.jpg
# Found clear image: neutral\brie_larson\000005.jpg
# Found clear image: neutral\brie_larson\000006.jpg
# Found clear image: neutral\brie_larson\000007.jpg
# Found clear image: neutral\brie_larson\000008.jpg
# Found clear image: neutral\brie_larson\000009.jpg
# Found clear image: neutral\brie_larson\000010.jpg
# Found clear image: neutral\brie_larson\000011.jpg
# Found clear image: neutral\brie_larson\000012.jpg
# Found clear image: neutral\brie_larson\000013.jpg
# Found clear image: neutral\brie_larson\000014.jpg
# Found clear image: neutral\brie_larson\000015.jpg
# Found clear image: neutral\brie_larson\000016.jpg
# Found clear image: neutral\brie_larson\000017.jpg
# Found clear image: neutral\brie_larson\000018.jpg
# Found clear image: neutral\brie_larson\000019.jpg
# Found clear image: neutral\brie_larson\000020.jpg
# Found clear image: neutral\brie_larson\000021.jpg
# Found clear image: neutral\brie_larson\000022.jpg
# Found clear image: neutral\brie_larson\000023.jpg
# Found clear image: neutral\brie_larson\000024.jpg
# Found clear image: neutral\brie_larson\000025.jpg
# Found clear image: neutral\brie_larson\000026.jpg
# Found clear image: neutral\brie_larson\000027.jpg
# Found clear image: neutral\brie_larson\000028.jpg
# Found clear image: neutral\brie_larson\000029.jpg
# Found clear image: neutral\brie_larson\000030.jpg
# Found clear image: neutral\brie_larson\000031.jpg
# Found clear image: neutral\brie_larson\000032.jpg
# Found clear image: neutral\brie_larson\000033.jpg
# Found clear image: neutral\brie_larson\000034.jpg
# Found clear image: neutral\brie_larson\000035.jpg
# Found clear image: neutral\brie_larson\000036.jpg
# Found clear image: neutral\brie_larson\000037.jpg
# Found clear image: neutral\brie_larson\000038.jpg
# Found clear image: neutral\brie_larson\000039.jpg
# Found clear image: neutral\brie_larson\000040.jpg
# Found clear image: neutral\brie_larson\000041.jpg
# Found clear image: neutral\brie_larson\000042.jpg
# Found clear image: neutral\brie_larson\000043.jpg
# Found clear image: neutral\brie_larson\000044.jpg
# Found clear image: neutral\brie_larson\000045.jpg
# Found clear image: neutral\brie_larson\000046.jpg
# Found clear image: neutral\brie_larson\000047.jpg
# Found clear image: neutral\brie_larson\000048.jpg
# Found clear image: neutral\brie_larson\000049.jpg
# Found clear image: neutral\brie_larson\000050.jpg
# Found clear image: neutral\brie_larson\000051.jpg
# Found clear image: neutral\bruce_willis\000001.jpg
# Found clear image: neutral\bruce_willis\000002.jpg
# Found clear image: neutral\bruce_willis\000003.jpg
# Found clear image: neutral\bruce_willis\000004.jpg
# Found clear image: neutral\bruce_willis\000005.jpg
# Found clear image: neutral\bruce_willis\000006.jpg
# Found clear image: neutral\bruce_willis\000007.jpg
# Found clear image: neutral\bruce_willis\000008.jpg
# Found clear image: neutral\bruce_willis\000009.jpg
# Found clear image: neutral\bruce_willis\000010.jpg
# Found clear image: neutral\bruce_willis\000011.jpg
# Found clear image: neutral\bruce_willis\000012.jpg
# Found clear image: neutral\bruce_willis\000013.jpg
# Found clear image: neutral\bruce_willis\000014.jpg
# Found clear image: neutral\bruce_willis\000015.jpg
# Found clear image: neutral\bryce_dallas_howard\000021.jpg
# Found clear image: neutral\bryce_dallas_howard\000022.jpg
# Found clear image: neutral\bryce_dallas_howard\000023.jpg
# Found clear image: neutral\bryce_dallas_howard\000024.jpg
# Found clear image: neutral\bryce_dallas_howard\000025.jpg
# Found clear image: neutral\bryce_dallas_howard\000026.jpg
# Found clear image: neutral\bryce_dallas_howard\000027.jpg
# Found clear image: neutral\bryce_dallas_howard\000028.jpg
# Found clear image: neutral\bryce_dallas_howard\000029.jpg
# Found clear image: neutral\bryce_dallas_howard\000030.jpg
# Found clear image: neutral\bryce_dallas_howard\000031.jpg
# Found clear image: neutral\bryce_dallas_howard\000032.jpg
# Found clear image: neutral\bryce_dallas_howard\000033.jpg
# Found clear image: neutral\bryce_dallas_howard\000034.jpg
# Found clear image: neutral\bryce_dallas_howard\000035.jpg
# Found clear image: neutral\bryce_dallas_howard\000036.jpg
# Found clear image: neutral\bryce_dallas_howard\000037.jpg
# Found clear image: neutral\bryce_dallas_howard\000038.jpg
# Found clear image: neutral\bryce_dallas_howard\000039.jpg
# Found clear image: neutral\bryce_dallas_howard\000040.jpg
# Found clear image: neutral\bryce_dallas_howard\000041.jpg
# Found clear image: neutral\carlos_sainz\000001.jpg
# Found clear image: neutral\carlos_sainz\000002.jpg
# Found clear image: neutral\carlos_sainz\000003.jpg
# Found clear image: neutral\carlos_sainz\000004.jpg
# Found clear image: neutral\carlos_sainz\000005.jpg
# Found clear image: neutral\carlos_sainz\000006.jpg
# Found clear image: neutral\carlos_sainz\000007.jpg
# Found clear image: neutral\carlos_sainz\000008.jpg
# Found clear image: neutral\carlos_sainz\000009.jpg
# Found clear image: neutral\carlos_sainz\000010.jpg
# Found clear image: neutral\carlos_sainz\000011.jpg
# Found clear image: neutral\carlos_sainz\000012.jpg
# Found clear image: neutral\carlos_sainz\000013.jpg
# Found clear image: neutral\carlos_sainz\000014.jpg
# Found clear image: neutral\carlos_sainz\000015.jpg
# Found clear image: neutral\carlos_sainz\000016.jpg
# Found clear image: neutral\carlos_sainz\000017.jpg
# Found clear image: neutral\carlos_sainz\000018.jpg
# Found clear image: neutral\carlos_sainz\000019.jpg
# Found clear image: neutral\carlos_sainz\000020.jpg
# Found clear image: neutral\carlos_sainz\000021.jpg
# Found clear image: neutral\carlos_sainz\000022.jpg
# Found clear image: neutral\carlos_sainz\000023.jpg
# Found clear image: neutral\carlos_sainz\000024.jpg
# Found clear image: neutral\carlos_sainz\000025.jpg
# Found clear image: neutral\carlos_sainz\000026.jpg
# Found clear image: neutral\carlos_sainz\000027.jpg
# Found clear image: neutral\carlos_sainz\000028.jpg
# Found clear image: neutral\carlos_sainz\000029.jpg
# Found clear image: neutral\carlos_sainz\000030.jpg
# Found clear image: neutral\carlos_sainz\000031.jpg
# Found clear image: neutral\charles_leclerc\000001.jpg
# Found clear image: neutral\charles_leclerc\000002.jpg
# Found clear image: neutral\charles_leclerc\000003.jpg
# Found clear image: neutral\charles_leclerc\000004.jpg
# Found clear image: neutral\charles_leclerc\000005.jpg
# Found clear image: neutral\chris_pratt\000028.jpg
# Found clear image: neutral\chris_pratt\000029.jpg
# Found clear image: neutral\chris_pratt\000030.jpg
# Found clear image: neutral\chris_pratt\000031.jpg
# Found clear image: neutral\chris_pratt\000032.jpg
# Found clear image: neutral\chris_pratt\000033.jpg
# Found clear image: neutral\chris_pratt\000034.jpg
# Found clear image: neutral\chris_pratt\000035.jpg
# Found clear image: neutral\chris_pratt\000036.jpg
# Found clear image: neutral\chris_pratt\000037.jpg
# Found clear image: neutral\chris_pratt\000038.jpg
# Found clear image: neutral\chris_pratt\000039.jpg
# Found clear image: neutral\chris_pratt\000040.jpg
# Found clear image: neutral\chris_pratt\000041.jpg
# Found clear image: neutral\chris_pratt\000042.jpg
# Found clear image: neutral\chris_pratt\000043.jpg
# Found clear image: neutral\chris_pratt\000044.jpg
# Found clear image: neutral\chris_pratt\000045.jpg
# Found clear image: neutral\chris_pratt\000046.jpg
# Found clear image: neutral\chris_pratt\000047.jpg
# Found clear image: neutral\chris_pratt\000048.jpg
# Found clear image: neutral\chris_pratt\000049.jpg
# Found clear image: neutral\chris_pratt\000050.jpg
# Found clear image: neutral\chris_pratt\000051.jpg
# Found clear image: neutral\chris_pratt\000052.jpg
# Found clear image: neutral\chris_pratt\000053.jpg
# Found clear image: neutral\chris_pratt\000054.jpg
# Found clear image: neutral\chris_pratt\000055.jpg
# Found clear image: neutral\chris_pratt\000056.jpg
# Found clear image: neutral\chris_pratt\000057.jpg
# Found clear image: neutral\chris_pratt\000058.jpg
# Found clear image: neutral\chris_pratt\000059.jpg
# Found clear image: neutral\chris_pratt\000060.jpg
# Found clear image: neutral\chuck_schumer\000001.jpg
# Found clear image: neutral\chuck_schumer\000002.jpg
# Found clear image: neutral\chuck_schumer\000003.jpg
# Found clear image: neutral\chuck_schumer\000004.jpg
# Found clear image: neutral\chuck_schumer\000005.jpg
# Found clear image: neutral\chuck_schumer\000006.jpg
# Found clear image: neutral\chuck_schumer\000007.jpg
# Found clear image: neutral\chuck_schumer\000008.jpg
# Found clear image: neutral\chuck_schumer\000009.jpg
# Found clear image: neutral\chuck_schumer\000010.jpg
# Found clear image: neutral\chuck_schumer\000011.jpg
# Found clear image: neutral\chuck_schumer\000012.jpg
# ...
# Found clear image: neutral\jennifer_lawrence\000027.jpg
# Found clear image: neutral\jennifer_lawrence\000028.jpg
# Found clear image: neutral\jennifer_lawrence\000029.jpg
# Found clear image: neutral\jennifer_lawrence\000030.jpg
# Found clear image: neutral\jennifer_lawrence\000031.jpg
# Found clear image: neutral\jennifer_lawrence\000032.jpg
# Found clear image: neutral\jennifer_lawrence\000033.jpg
# Found clear image: neutral\jennifer_lawrence\000034.jpg
# Found clear image: neutral\jennifer_lawrence\000035.jpg
# Found clear image: neutral\jennifer_lawrence\000036.jpg
# Found clear image: neutral\jennifer_lawrence\000037.jpg
# Found clear image: neutral\jennifer_lawrence\000038.jpg
# Found clear image: neutral\jennifer_lawrence\000039.jpg
# Found clear image: neutral\jennifer_lawrence\000040.jpg
# Found clear image: neutral\john_boyega\000002.jpg
# Found clear image: neutral\john_boyega\000003.jpg
# Found clear image: neutral\john_boyega\000004.jpg
# Found clear image: neutral\john_boyega\000005.jpg
# Found clear image: neutral\john_boyega\000006.jpg
# Found clear image: neutral\john_boyega\000007.jpg
# Found clear image: neutral\john_boyega\000008.jpg
# Found clear image: neutral\john_boyega\000009.jpg
# Found clear image: neutral\john_boyega\000010.jpg
# Found clear image: neutral\john_boyega\000011.jpg
# Found clear image: neutral\john_boyega\000012.jpg
# Found clear image: neutral\john_boyega\000013.jpg
# Found clear image: neutral\john_boyega\000014.jpg
# Found clear image: neutral\john_boyega\000015.jpg
# Found clear image: neutral\john_boyega\000016.jpg
# Found clear image: neutral\john_boyega\000017.jpg
# Found clear image: neutral\john_boyega\000018.jpg
# Found clear image: neutral\john_boyega\000019.jpg
# Found clear image: neutral\john_boyega\000020.jpg
# Found clear image: neutral\john_boyega\000021.jpg
# Found clear image: neutral\john_boyega\000022.jpg
# Found clear image: neutral\john_boyega\000023.jpg
# Found clear image: neutral\john_boyega\000024.jpg
# Found clear image: neutral\john_boyega\000025.jpg
# Found clear image: neutral\john_boyega\000026.jpg
# Found clear image: neutral\john_boyega\000027.jpg
# Found clear image: neutral\john_boyega\000028.jpg
# Found clear image: neutral\john_boyega\000029.jpg
# Found clear image: neutral\john_boyega\000030.jpg
# Found clear image: neutral\john_boyega\000031.jpg
# Found clear image: neutral\john_boyega\000032.jpg
# Found clear image: neutral\john_boyega\000033.jpg
# Found clear image: neutral\john_boyega\000034.jpg
# Found clear image: neutral\john_boyega\000035.jpg
# Found clear image: neutral\john_boyega\000036.jpg
# Found clear image: neutral\john_boyega\000037.jpg
# Found clear image: neutral\john_boyega\000038.jpg
# Found clear image: neutral\john_boyega\000039.jpg
# Found clear image: neutral\john_boyega\000040.jpg
# Found clear image: neutral\john_boyega\000041.jpg
# Found clear image: neutral\john_boyega\000042.jpg
# Found clear image: neutral\john_boyega\000043.jpg
# Found clear image: neutral\john_boyega\000044.jpg
# Found clear image: neutral\john_boyega\000045.jpg
# Found clear image: neutral\john_boyega\000046.jpg
# Found clear image: neutral\john_boyega\000047.jpg
# Found clear image: neutral\john_boyega\000048.jpg
# Found clear image: neutral\john_boyega\000049.jpg
# Found clear image: neutral\john_boyega\000050.jpg
# Found clear image: neutral\john_boyega\000051.jpg
# Found clear image: neutral\john_boyega\000052.jpg
# Found clear image: neutral\john_boyega\000053.jpg
# Found clear image: neutral\john_boyega\000054.jpg
# Found clear image: neutral\john_boyega\000055.jpg
# Found clear image: neutral\john_boyega\000056.jpg
# Found clear image: neutral\john_boyega\000057.jpg
# Found clear image: neutral\john_goodman\000001.jpg
# Found clear image: neutral\john_goodman\000002.jpg
# Found clear image: neutral\john_goodman\000003.jpg
# Found clear image: neutral\john_goodman\000004.jpg
# Found clear image: neutral\john_goodman\000005.jpg
# Found clear image: neutral\john_goodman\000006.jpg
# Found clear image: neutral\john_goodman\000007.jpg
# Found clear image: neutral\john_goodman\000008.jpg
# Found clear image: neutral\john_goodman\000009.jpg
# Found clear image: neutral\john_goodman\000010.jpg
# Found clear image: neutral\john_goodman\000011.jpg
# Found clear image: neutral\john_goodman\000012.jpg
# Found clear image: neutral\john_goodman\000013.jpg
# Found clear image: neutral\john_goodman\000014.jpg
# Found clear image: neutral\john_goodman\000015.jpg
# Found clear image: neutral\john_goodman\000016.jpg
# Found clear image: neutral\john_goodman\000017.jpg
# Found clear image: neutral\john_goodman\000018.jpg
# Found clear image: neutral\john_goodman\000019.jpg
# Found clear image: neutral\john_ratzenberger\000001.jpg
# Found clear image: neutral\john_ratzenberger\000002.jpg
# Found clear image: neutral\john_ratzenberger\000003.jpg
# Found clear image: neutral\john_ratzenberger\000004.jpg
# Found clear image: neutral\john_ratzenberger\000005.jpg
# Found clear image: neutral\john_ratzenberger\000006.jpg
# Found clear image: neutral\john_ratzenberger\000007.jpg
# Found clear image: neutral\john_ratzenberger\000008.jpg
# Found clear image: neutral\john_ratzenberger\000009.jpg
# Found clear image: neutral\john_ratzenberger\000010.jpg
# Found clear image: neutral\john_ratzenberger\000011.jpg
# Found clear image: neutral\john_ratzenberger\000012.jpg
# Found clear image: neutral\john_ratzenberger\000013.jpg
# Found clear image: neutral\john_ratzenberger\000014.jpg
# Found clear image: neutral\john_ratzenberger\000015.jpg
# Found clear image: neutral\john_ratzenberger\000016.jpg
# Found clear image: neutral\john_ratzenberger\000017.jpg
# Found clear image: neutral\john_ratzenberger\000018.jpg
# Found clear image: neutral\john_ratzenberger\000019.jpg
# Found clear image: neutral\john_ratzenberger\000020.jpg
# Found clear image: neutral\john_ratzenberger\000021.jpg
# Found clear image: neutral\john_travolta\000001.jpg
# Found clear image: neutral\john_travolta\000002.jpg
# Found clear image: neutral\john_travolta\000003.jpg
# Found clear image: neutral\john_travolta\000004.jpg
# Found clear image: neutral\john_travolta\000005.jpg
# Found clear image: neutral\john_travolta\000006.jpg
# Found clear image: neutral\john_travolta\000007.jpg
# Found clear image: neutral\john_travolta\000008.jpg
# Found clear image: neutral\john_travolta\000009.jpg
# Found clear image: neutral\john_travolta\000010.jpg
# Found clear image: neutral\john_travolta\000011.jpg
# Found clear image: neutral\john_travolta\000012.jpg
# Found clear image: neutral\john_travolta\000013.jpg
# Found clear image: neutral\john_travolta\000014.jpg
# Found clear image: neutral\john_travolta\000015.jpg
# Found clear image: neutral\john_travolta\000016.jpg
# Found clear image: neutral\john_travolta\000017.jpg
# Found clear image: neutral\john_travolta\000018.jpg
# Found clear image: neutral\john_travolta\000019.jpg
# Found clear image: neutral\john_travolta\000020.jpg
# Found clear image: neutral\john_travolta\000021.jpg
# Found clear image: neutral\john_travolta\000022.jpg

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LaplacianPriorNet(nn.Module):
    def __init__(self):
        super(LaplacianPriorNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1, bias=False)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, 128, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        return x

class LRMatchModule(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(LRMatchModule, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x_flipped = torch.flip(x, dims=[3])
        return x, x_flipped

class CodeConversionModule(nn.Module):
    def __init__(self, in_features, out_features):
        super(CodeConversionModule, self).__init__()
        self.fc = nn.Linear(in_features, out_features)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

class SILPAutoencoder(nn.Module):
    def __init__(self, in_channels=3, out_channels=3):
        super(SILPAutoencoder, self).__init__()
        self.laplacian_prior_net = LaplacianPriorNet()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(64, 64),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(128, 128),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(256, 256),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.code_conversion = CodeConversionModule(256 * 8 * 8, 1024)
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(1024, 256, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(256, 256),
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(128, 128),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(64, 64),
            nn.Conv2d(64, out_channels, kernel_size=3, padding=1)
        )

    def forward(self, x):
        laplacian_features = self.laplacian_prior_net(x)
        encoded = self.encoder(x)
        code = self.code_conversion(encoded)
        code = code.view(code.size(0), 1024, 1, 1)
        decoded = self.decoder(code)
        return decoded

# %%
def pixel_loss(output, target):
    target_size = target.size()
    if len(target_size) == 4:
        c, h, w = target_size[1], target_size[2], target_size[3]
    else:
        c, h, w = target_size[0], 1, 1
    loss = nn.MSELoss(reduction='sum')(output, target) / (c * h * w)
    return loss



def lr_average_loss(output, target):
    c, h, w = target.size(1), target.size(2), target.size(3)
    avg_pool = nn.AvgPool2d(kernel_size=3, stride=1, padding=1)
    I_b = torch.norm(avg_pool(target) - torch.flip(avg_pool(target), dims=[3]), p=1, dim=1)
    I_hat = torch.norm(avg_pool(output) - torch.flip(avg_pool(output), dims=[3]), p=1, dim=1)

    loss = nn.L1Loss(reduction='sum')(I_b, I_hat) / (c * h * w)
    return loss
    
def perceptual_loss(output, target, vgg_model):
    output_features = vgg_model(output)
    target_features = vgg_model(target)
    loss = 0
    for output_feature, target_feature in zip(output_features, target_features):
        loss += nn.L1Loss(reduction='sum')(output_feature, target_feature) / output_feature.numel()
    return loss

def w_smooth_loss(output, target):
    diff_H = torch.abs(output[:, :, :-1, :] - output[:, :, 1:, :])
    diff_W = torch.abs(output[:, :, :, :-1] - output[:, :, :, 1:])
    loss = torch.mean(diff_H) + torch.mean(diff_W)
    return loss

# %%
class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_paths = self.load_image_paths()

    def load_image_paths(self):
        image_paths = []
        for subdir in os.listdir(self.root_dir):
            subdir_path = os.path.join(self.root_dir, subdir)
            if os.path.isdir(subdir_path):
                for filename in os.listdir(subdir_path):
                    image_path = os.path.join(subdir_path, filename)
                    image_paths.append(image_path)
        return image_paths

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        try:
            img = Image.open(img_path).convert('RGB')
            if self.transform:
                img = self.transform(img)
            return img
        except UnidentifiedImageError as e:
            print(f"Error opening image: {img_path}. Skipping this image.")
            return None

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision.models import vgg16
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset

class LaplacianPriorNet(nn.Module):
    def __init__(self, out_channels):
        super(LaplacianPriorNet, self).__init__()
        self.conv1 = nn.Conv2d(3, out_channels, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        out = self.conv1(x)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.relu(out)
        return out

class SILPAutoencoder(nn.Module):
    def __init__(self, out_channels, in_features, out_features):
        super(SILPAutoencoder, self).__init__()
        self.laplacian_prior_net = LaplacianPriorNet(out_channels)
        self.encoder = nn.Sequential(
            nn.Conv2d(out_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        # Calculate the size of the feature maps after the encoder
        with torch.no_grad():
            dummy_input = torch.zeros(1, out_channels, 224, 224)
            encoder_output_size = self.encoder(dummy_input).view(1, -1).size(1)
        self.code_conversion = nn.Linear(encoder_output_size, out_features)  # Adjusted input size
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 3, kernel_size=3, padding=1),
            nn.Sigmoid()
        )
        self.upsample = nn.Upsample(size=(224, 224), mode='bilinear', align_corners=True)

    def forward(self, x):
        laplacian_features = self.laplacian_prior_net(x)
        encoded = self.encoder(laplacian_features)
        # Flatten the encoder output before passing to the linear layer
        code = self.code_conversion(encoded.view(encoded.size(0), -1))
        decoded = self.decoder(code.view(code.size(0), -1, 1, 1))
        outputs = self.upsample(decoded)
        return outputs

from PIL import UnidentifiedImageError


# Set up the training process
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
out_channels = 128  # Example output channels of LaplacianPriorNet
in_features = 224
out_features = 128  # Example output dimension of decoder
num_epochs = 10 

# Define transformations for the dataset
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Load datasets
occluded_dataset = CustomDataset(root_dir=r'C:\Users\dk\Documents\silp\occluded\masked', transform=transform)
clear_dataset = CustomDataset(root_dir=r'C:\Users\dk\Documents\silp\neutral', transform=transform)

# Define data loaders
batch_size = 32
occluded_data_loader = DataLoader(occluded_dataset, batch_size=batch_size, shuffle=True)
clear_data_loader = DataLoader(clear_dataset, batch_size=batch_size, shuffle=True)

# Assuming you have a pretrained VGG model
vgg_model = vgg16(pretrained=True).features.to(device).eval() 

model = SILPAutoencoder(out_channels, in_features, out_features).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

for epoch in range(num_epochs):
    for occluded_images, clear_images in zip(occluded_data_loader, clear_data_loader):
        occluded_images = occluded_images.to(device)
        clear_images = clear_images.to(device)

        # Calculate the losses
        outputs = model(occluded_images)

        # Resize outputs to match the size of clear_images
        outputs_resized = torch.nn.functional.interpolate(outputs, size=clear_images.shape[2:], mode='bilinear', align_corners=False)

        pixel_loss_value = pixel_loss(outputs_resized, clear_images)
        perceptual_loss_value = perceptual_loss(outputs_resized, clear_images, vgg_model)
        lr_average_loss_value = lr_average_loss(outputs_resized, clear_images)
        w_smooth_loss_value = w_smooth_loss(outputs_resized, clear_images)
        k1, k2, k3, k4 = 1, 0.25, 0.1, 0.1
        total_loss = k1 * pixel_loss_value + k2 * perceptual_loss_value + k3 * lr_average_loss_value + k4 * w_smooth_loss_value

        # Backpropagate and update the model
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()
# Out:
# Error opening image: C:\Users\dk\Documents\silp\occluded\masked\rafael_nadal_wearing_mask\000008.jpg. Skipping this image.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 119
#     116 optimizer = optim.Adam(model.parameters(), lr=0.001)
#     118 for epoch in range(num_epochs):
# --> 119     for occluded_images, clear_images in zip(occluded_data_loader, clear_data_loader):
#     120         occluded_images = occluded_images.to(device)
#     121         clear_images = clear_images.to(device)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\_utils\collate.py:277, in default_collate(batch)
#     216 def default_collate(batch):
#     217     r"""
#     218     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     219
#    (...)
#     275         >>> default_collate(batch)  # Handle `CustomType` automatically
#     276     """
# --> 277     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\_utils\collate.py:121, in collate(batch, collate_fn_map)
#     119 if collate_fn_map is not None:
#     120     if elem_type in collate_fn_map:
# --> 121         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     123     for collate_type in collate_fn_map:
#     124         if isinstance(elem, collate_type):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\data\_utils\collate.py:174, in collate_tensor_fn(batch, collate_fn_map)
#     172     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     173     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 174 return torch.stack(batch, 0, out=out)
#
# TypeError: expected Tensor as element 20 in argument 0, but got NoneType

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class LaplacianPriorSubnetwork(nn.Module):
    def __init__(self):
        super(LaplacianPriorSubnetwork, self).__init__()
        # Fixed convolutional layer with Laplace operator kernel
        self.laplace_conv = nn.Conv2d(1, 1, kernel_size=3, bias=False)
        self.laplace_conv.weight.data = torch.Tensor([[[[0, 1, 0],
                                                         [1, -4, 1],
                                                         [0, 1, 0]]]])
        self.laplace_conv.weight.requires_grad = False

        # Two convolutional layers from VGG-16 block1 (pretrained, frozen)
        self.vgg_layers = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )
        for param in self.vgg_layers.parameters():
            param.requires_grad = False

    def forward(self, x):
        x = self.laplace_conv(x)
        x = self.vgg_layers(x)
        return x

class LRMatchModule(nn.Module):
    def __init__(self, in_channels, out_channels, is_deconv=False):
        super(LRMatchModule, self).__init__()
        if is_deconv:
            self.conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size=3, padding=1)
        else:
            self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)

    def forward(self, x):
        x = self.conv(x)
        x_flipped = torch.flip(x, dims=[3])  # Flip along the width dimension
        out = (x + x_flipped) / 2  # Take the average of original and flipped features
        return out

class CodeConversionModule(nn.Module):
    def __init__(self, in_channels, hidden_dim):
        super(CodeConversionModule, self).__init__()
        self.fc = nn.Linear(in_channels, hidden_dim)

    def forward(self, x):
        batch_size, channels, height, width = x.size()
        x = x.view(batch_size, channels * height * width)
        x = self.fc(x)
        return x

class SILPAutoencoder(nn.Module):
    def __init__(self, input_channels=3, hidden_dim=500):
        super(SILPAutoencoder, self).__init__()
        self.laplacian_prior = LaplacianPriorSubnetwork()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(64, 64),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(128, 128),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(256, 256),
            nn.MaxPool2d(2, stride=2)
        )

        self.code_conversion = CodeConversionModule(256 * 8 * 8, hidden_dim)

        # Decoder
        self.decoder = nn.Sequential(
            LRMatchModule(256 + hidden_dim, 256, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2),

            LRMatchModule(128, 128, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2),

            LRMatchModule(64, 64, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 1, kernel_size=2, stride=2),
            nn.Tanh()
        )

    def forward(self, x):
        laplacian_prior = self.laplacian_prior(x)

        encoded = self.encoder(x)
        batch_size, channels, height, width = encoded.size()
        code = self.code_conversion(encoded.view(batch_size, channels, height * width))
        code = code.view(batch_size, -1, 1, 1)

        combined_code = torch.cat((encoded, code), dim=1)
        reconstructed = self.decoder(combined_code)

        return reconstructed, laplacian_prior

# Example usage
model = SILPAutoencoder()

# %%
import cv2
import random
import cv2
from matplotlib import pyplot as plt
def apply_occlusion(image_path):
    image = cv2.imread(image_path)
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    for (x, y, w, h) in faces:
        occlusion_x = x + random.randint(0, w)
        occlusion_y = y + random.randint(0, h)
        occlusion_width = random.randint(10, int(w * 0.5))
        occlusion_height = random.randint(10, int(h * 0.5))
        cv2.rectangle(image, (occlusion_x, occlusion_y), (occlusion_x + occlusion_width, occlusion_y + occlusion_height), (0, 0, 0), -1)
    
    # Display the image with occlusion"
    plt.imshow(image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Now you can call this function with the image path as input
image_path = 'Screenshot 2024-03-23 123957.png'
apply_occlusion(image_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 5
#       3 import cv2
#       4 from matplotlib import pyplot as plt
# ----> 5 from patches import cv2show
#       6 def apply_occlusion(image_path):
#       7     image = cv2.imread(image_path)
#
# ModuleNotFoundError: No module named 'patches'

# %%
import cv2
import torch
import numpy as np
from torchvision import transforms

class SILPAutoencoder(nn.Module):
    def __init__(self, input_channels=1, hidden_dim=500):
        super(SILPAutoencoder, self).__init__()
        self.laplacian_prior = LaplacianPriorSubnetwork()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(input_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(64, 64),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(128, 128),
            nn.MaxPool2d(2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            LRMatchModule(256, 256),
            nn.MaxPool2d(2, stride=2)
        )

        self.code_conversion = CodeConversionModule(256 * 8 * 8, hidden_dim)

        # Decoder
        self.decoder = nn.Sequential(
            LRMatchModule(256 + hidden_dim, 256, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2),

            LRMatchModule(128, 128, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2),

            LRMatchModule(64, 64, is_deconv=True),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(64, 1, kernel_size=2, stride=2),
            nn.Tanh()
        )

    def forward(self, x):
        laplacian_prior = self.laplacian_prior(x)

        encoded = self.encoder(x)
        batch_size, channels, height, width = encoded.size()
        code = self.code_conversion(encoded)
        code = code.view(batch_size, -1, 1, 1)

        combined_code = torch.cat((encoded, code), dim=1)
        reconstructed = self.decoder(combined_code)

        return reconstructed, laplacian_prior

class CodeConversionModule(nn.Module):
    def __init__(self, in_channels, hidden_dim):
        super(CodeConversionModule, self).__init__()
        self.fc = nn.Linear(in_channels, hidden_dim)

    def forward(self, x):
        batch_size, channels, height, width = x.size()
        x = x.view(batch_size, -1)  # Flatten the input
        x = self.fc(x)
        return x


# Load the image
image_path = 'Screenshot 2024-03-23 123957.png'
image = cv2.imread(image_path)
occluded_images = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Convert numpy array to PyTorch tensor
occluded_images_tensor = torch.tensor(occluded_images, dtype=torch.float32)

# Add a singleton dimension for the channel
occluded_images_tensor = occluded_images_tensor.unsqueeze(0).unsqueeze(0)

# Instantiate the SILPAutoencoder model
model = SILPAutoencoder(input_channels=1)

# Pass the tensor through the model
reconstructed_images, laplacian_prior = model(occluded_images_tensor)

# Convert the reconstructed images back to numpy array
reconstructed_images_np = reconstructed_images.detach().numpy().squeeze()

# Display the original and reconstructed images
plt.imshow(occluded_images)
plt.imshow(reconstructed_images_np)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 87
#      84 model = SILPAutoencoder(input_channels=1)
#      86 # Pass the tensor through the model
# ---> 87 reconstructed_images, laplacian_prior = model(occluded_images_tensor)
#      89 # Convert the reconstructed images back to numpy array
#      90 reconstructed_images_np = reconstructed_images.detach().numpy().squeeze()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[19], line 52, in SILPAutoencoder.forward(self, x)
#      50 encoded = self.encoder(x)
#      51 batch_size, channels, height, width = encoded.size()
# ---> 52 code = self.code_conversion(encoded)
#      53 code = code.view(batch_size, -1, 1, 1)
#      55 combined_code = torch.cat((encoded, code), dim=1)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[19], line 68, in CodeConversionModule.forward(self, x)
#      66 batch_size, channels, height, width = x.size()
#      67 x = x.view(batch_size, -1)  # Flatten the input
# ---> 68 x = self.fc(x)
#      69 return x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x143360 and 16384x500)
